# %% [markdown]
# # Python Algorithm

# %% [markdown]
# |   #  |题目       |   我的题解  |   难度  | 完成情况  |
# | :- | :- | :- | :- | :-: |
# | 1🔥 |[Two Sum](https://leetcode.com/problems/two-sum)|[Python](./code/1.ipynb)|Easy| ☑ |
# | 2🔥 |[Add Two Numbers](https://leetcode.com/problems/add-two-numbers)|[Python](./code/2.ipynb)|Medium| ☑   |
# | 3🔥 |[Longest Substring Without Repeating Characters](https://leetcode.com/problems/longest-substring-without-repeating-characters)|[Python](./code/3.ipynb)|Medium| ☑ |
# | 4🔥 |[Median of Two Sorted Arrays](https://leetcode.com/problems/median-of-two-sorted-arrays/)|[Python](./code/4.ipynb)|Hard| ☑ |
# | 5🔥 |[Longest Palindromic Substring](https://leetcode.com/problems/longest-palindromic-substring)|[Python](./code/5.ipynb)|Medium| ☑ |
# | 6 |[ZigZag Conversion](https://leetcode.com/problems/zigzag-conversion)|[Python](./code/6.ipynb)|Medium|  ☑  |
# | 7 |[Reverse Integer](https://leetcode.com/problems/reverse-integer)|[Python](./code/7.ipynb)|Easy| ☑ |
# | 8 |[String to Integer (atoi)](https://leetcode.com/problems/string-to-integer-atoi)|[Python](./code/8.ipynb)|Medium| ☑ |
# | 9 |[Palindrome Number](https://leetcode.com/problems/palindrome-number)|[Python](./code/9.ipynb)|Easy|☑  |
# | 10🔥 |[Regular Expression Matching](https://leetcode.com/problems/regular-expression-matching/)|[Python](./code/10.ipynb)|Hard| ☑ |
# | 11🔥 |[Container With Most Water](https://leetcode.com/problems/container-with-most-water)|[Python](./code/11.ipynb)|Medium| ☑ |
# | 12 |[Integer to Roman](https://leetcode.com/problems/integer-to-roman)|[Python](./code/12.ipynb)|Medium| ☑ |
# | 13 |[Roman to Integer](https://leetcode.com/problems/roman-to-integer)|[Python](./code/13.ipynb)|Easy| ☑  |
# | 14 |[Longest Common Prefix](https://leetcode.com/problems/longest-common-prefix)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 15🔥 |[3Sum](https://leetcode.com/problems/3sum)|[Python](./code/15.ipynb)|Medium| ☑ |
# | 16 |[3Sum Closest](https://leetcode.com/problems/3sum-closest)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 17🔥 |[Letter Combinations of a Phone Number](https://leetcode.com/problems/letter-combinations-of-a-phone-number)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 18 |[4Sum](https://leetcode.com/problems/4sum)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 19🔥 |[Remove Nth Node From End of List](https://leetcode.com/problems/remove-nth-node-from-end-of-list)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 20🔥 |[Valid Parentheses](https://leetcode.com/problems/valid-parentheses)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 21🔥 |[Merge Two Sorted Lists](https://leetcode.com/problems/merge-two-sorted-lists)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 22🔥 |[Generate Parentheses](https://leetcode.com/problems/generate-parentheses)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 23🔥 |[Merge k Sorted Lists](https://leetcode.com/problems/merge-k-sorted-lists/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 24 |[Swap Nodes in Pairs](https://leetcode.com/problems/swap-nodes-in-pairs)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 26 |[Remove Duplicates from Sorted Array](https://leetcode.com/problems/remove-duplicates-from-sorted-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 27 |[Remove Element](https://leetcode.com/problems/remove-element)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 28 |[Implement strStr()](https://leetcode.com/problems/implement-strstr/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 29 |[Divide Two Integers](https://leetcode.com/problems/divide-two-integers)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 31🔥 |[Next Permutation](https://leetcode.com/problems/next-permutation)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 32🔥 |[Longest Valid Parentheses](https://leetcode.com/problems/longest-valid-parentheses/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 33🔥 |[Search in Rotated Sorted Array](https://leetcode.com/problems/search-in-rotated-sorted-array/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 34🔥 |[Find First and Last Position of Element in Sorted ](https://leetcode.com/problems/find-first-and-last-position-of-element-in-sorted-array/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 35 |[Search Insert Position](https://leetcode.com/problems/search-insert-position)|[Python](./code/Untitled.ipynb)|Easy|  |
# |36  |[Valid Sudoku](https://leetcode.com/problems/valid-sudoku/) |[Python](./code/Untitled.ipynb)|Medium| |
# | 38 |[Count and Say](https://leetcode.com/problems/count-and-say)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 39🔥 |[Combination Sum](https://leetcode.com/problems/combination-sum/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 40 |[Combination Sum II](https://leetcode.com/problems/combination-sum-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 41 |[First Missing Positive](https://leetcode.com/problems/first-missing-positive/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 42🔥 |[Trapping Rain Water](https://leetcode.com/problems/trapping-rain-water/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 43 |[Multiply Strings](https://leetcode.com/problems/multiply-strings/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 44 |[Wildcard Matching](https://leetcode.com/problems/wildcard-matching/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 45 |[Jump Game II](https://leetcode.com/problems/jump-game-ii/) |[Python](./code/Untitled.ipynb)|Hard|  |
# | 46🔥 |[Permutations](https://leetcode.com/problems/permutations/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 47 |[Permutations II](https://leetcode.com/problems/permutations-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 48🔥 |[Rotate Image](https://leetcode.com/problems/rotate-image/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 49🔥 |[Group Anagrams](https://leetcode.com/problems/group-anagrams/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 50 |[Pow(x, n)](https://leetcode.com/problems/powx-n/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 53🔥 |[Maximum Subarray](https://leetcode.com/problems/maximum-subarray)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 54 |[Spiral Matrix](https://leetcode.com/problems/spiral-matrix/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 55🔥 |[Jump Game](https://leetcode.com/problems/jump-game/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 56🔥 |[Merge Intervals](https://leetcode.com/problems/merge-intervals/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 58 |[Length of Last Word](https://leetcode.com/problems/length-of-last-word)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 59 |[Spiral Matrix II](https://leetcode.com/problems/spiral-matrix-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 60 |[Permutation Sequence](https://leetcode.com/problems/permutation-sequence/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 61 |[Rotate List](https://leetcode.com/problems/rotate-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 62🔥 |[Unique Paths](https://leetcode.com/problems/unique-paths/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 63 |[Unique Paths II](https://leetcode.com/problems/unique-paths-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 64🔥 |[Minimum Path Sum](https://leetcode.com/problems/minimum-path-sum/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 65 |[Valid Number](https://leetcode.com/problems/valid-number/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 66 |[Plus One](https://leetcode.com/problems/plus-one)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 67 |[Add Binary](https://leetcode.com/problems/add-binary)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 69 |[Sqrt(x)](https://leetcode.com/problems/sqrtx)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 70🔥 |[Climbing Stairs](https://leetcode.com/problems/climbing-stairs)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 71 |[Simplify Path](https://leetcode.com/problems/simplify-path/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 72🔥 |[Edit Distance](https://leetcode.com/problems/edit-distance/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 73 |[Set Matrix Zeroes](https://leetcode.com/problems/set-matrix-zeroes/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 74 |[Search a 2D Matrix](https://leetcode.com/problems/search-a-2d-matrix/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 75🔥 |[Sort Colors](https://leetcode.com/problems/sort-colors/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 76🔥 |[Minimum Window Substring](https://leetcode.com/problems/minimum-window-substring/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 77 |[Combinations](https://leetcode.com/problems/combinations/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 78🔥 |[Subsets](https://leetcode.com/problems/subsets/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 79🔥 |[Word Search](https://leetcode.com/problems/word-search/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 80 |[Remove Duplicates from Sorted Array II](https://leetcode.com/problems/remove-duplicates-from-sorted-array-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 81 |[Search in Rotated Sorted Array II](https://leetcode.com/problems/search-in-rotated-sorted-array-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 82 |[Remove Duplicates from Sorted List II](https://leetcode.com/problems/remove-duplicates-from-sorted-list-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 83 |[Remove Duplicates from Sorted List](https://leetcode.com/problems/remove-duplicates-from-sorted-list)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 84🔥 |[Largest Rectangle in Histogram](https://leetcode.com/problems/largest-rectangle-in-histogram/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 85🔥 |[Maximal Rectangle](https://leetcode.com/problems/maximal-rectangle/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 86 |[Partition List](https://leetcode.com/problems/partition-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 88 |[Merge Sorted Array](https://leetcode.com/problems/merge-sorted-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 89 |[Gray Code](https://leetcode.com/problems/gray-code/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 90 |[Subsets II](https://leetcode.com/problems/subsets-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 91 |[Decode Ways](https://leetcode.com/problems/decode-ways/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 92 |[Reverse Linked List II](https://leetcode.com/problems/reverse-linked-list-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 93 |[Restore IP Addresses](https://leetcode.com/problems/restore-ip-addresses/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 94🔥 |[Binary Tree Inorder Traversal](https://leetcode.com/problems/binary-tree-inorder-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 95 |[Unique Binary Search Trees II](https://leetcode.com/problems/unique-binary-search-trees-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 96🔥 |[Unique Binary Search Trees](https://leetcode.com/problems/unique-binary-search-trees/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 98🔥 |[Validate Binary Search Tree](https://leetcode.com/problems/validate-binary-search-tree/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 100 |[Same Tree](https://leetcode.com/problems/same-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 101🔥 |[Symmetric Tree](https://leetcode.com/problems/symmetric-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 102🔥 |[Binary Tree Level Order Traversal](https://leetcode.com/problems/binary-tree-level-order-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 103 |[Binary Tree Zigzag Level Order Traversal](https://leetcode.com/problems/binary-tree-zigzag-level-order-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 104🔥 |[Maximum Depth of Binary Tree](https://leetcode.com/problems/maximum-depth-of-binary-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 105🔥 |[Construct Binary Tree from Preorder and Inorder Traversal](https://leetcode.com/problems/construct-binary-tree-from-preorder-and-inorder-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 106 |[Construct Binary Tree from Inorder and Postorder Traversal](https://leetcode.com/problems/construct-binary-tree-from-inorder-and-postorder-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 107 |[Binary Tree Level Order Traversal II](https://leetcode.com/problems/binary-tree-level-order-traversal-ii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 108 |[Convert Sorted Array to Binary Search Tree](https://leetcode.com/problems/convert-sorted-array-to-binary-search-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 109 |[Convert Sorted List to Binary Search Tree](https://leetcode.com/problems/convert-sorted-list-to-binary-search-tree/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 110 |[Balanced Binary Tree](https://leetcode.com/problems/balanced-binary-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 111 |[Minimum Depth of Binary Tree](https://leetcode.com/problems/minimum-depth-of-binary-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 112 |[Path Sum](https://leetcode.com/problems/path-sum)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 113 |[Path Sum II](https://leetcode.com/problems/path-sum-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 114🔥 |[Flatten Binary Tree to Linked List](https://leetcode.com/problems/flatten-binary-tree-to-linked-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 116 |[Populating Next Right Pointers in Each Node](https://leetcode.com/problems/populating-next-right-pointers-in-each-node/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 117 |[Populating Next Right Pointers in Each Node II](https://leetcode.com/problems/populating-next-right-pointers-in-each-node-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 118 |[Pascal's Triangle](https://leetcode.com/problems/pascals-triangle)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 119 |[Pascal's Triangle II](https://leetcode.com/problems/pascals-triangle-ii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 120 |[Triangle](https://leetcode.com/problems/triangle/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 121🔥 |[Best Time to Buy and Sell Stock](https://leetcode.com/problems/best-time-to-buy-and-sell-stock)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 122 |[Best Time to Buy and Sell Stock II](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 123 |[Best Time to Buy and Sell Stock III](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-iii/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 124🔥 |[Binary Tree Maximum Path Sum](https://leetcode.com/problems/binary-tree-maximum-path-sum/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 125 |[Valid Palindrome](https://leetcode.com/problems/valid-palindrome)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 127 |[Word Ladder](https://leetcode.com/problems/word-ladder/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 128🔥 |[Longest Consecutive Sequence](https://leetcode.com/problems/longest-consecutive-sequence/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 129 |[Sum Root to Leaf Numbers](https://leetcode.com/problems/sum-root-to-leaf-numbers/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 130 |[Surrounded Regions](https://leetcode.com/problems/surrounded-regions/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 131 |[Palindrome Partitioning](https://leetcode.com/problems/palindrome-partitioning/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 133 |[Clone Graph](https://leetcode.com/problems/clone-graph/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 134 |[Gas Station](https://leetcode.com/problems/gas-station/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 136🔥 |[Single Number](https://leetcode.com/problems/single-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 137 |[Single Number II](https://leetcode.com/problems/single-number-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 138 |[Copy List with Random Pointer](https://leetcode.com/problems/copy-list-with-random-pointer/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 139🔥 |[Word Break](https://leetcode.com/problems/word-break/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 140 |[Word Break II](https://leetcode.com/problems/word-break-ii/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 141🔥 |[Linked List Cycle](https://leetcode.com/problems/linked-list-cycle)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 142🔥 |[Linked List Cycle II](https://leetcode.com/problems/linked-list-cycle-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 143 |[Reorder List](https://leetcode.com/problems/reorder-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 144 |[Binary Tree Preorder Traversal](https://leetcode.com/problems/binary-tree-preorder-traversal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 146🔥 |[LRU Cache](https://leetcode.com/problems/lru-cache/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 148🔥|[Sort List](https://leetcode.com/problems/sort-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 149 |[Max Points on a Line](https://leetcode.com/problems/max-points-on-a-line/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 150 |[Evaluate Reverse Polish Notation](https://leetcode.com/problems/evaluate-reverse-polish-notation/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 151 |[Reverse Words in a String](https://leetcode.com/problems/reverse-words-in-a-string/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 152🔥 |[Maximum Product Subarray](https://leetcode.com/problems/maximum-product-subarray/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 153 |[Find Minimum in Rotated Sorted Array](https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 155🔥 |[Min Stack](https://leetcode.com/problems/min-stack)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 160🔥 |[Intersection of Two Linked Lists](https://leetcode.com/problems/intersection-of-two-linked-lists)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 162 |[Find Peak Element](https://leetcode.com/problems/find-peak-element/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 165 |[Compare Version Numbers](https://leetcode.com/problems/compare-version-numbers/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 166 |[Fraction to Recurring Decimal](https://leetcode.com/problems/fraction-to-recurring-decimal/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 167 |[Two Sum II - Input array is sorted](https://leetcode.com/problems/two-sum-ii---input-array-is-sorted)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 168 |[Excel Sheet Column Title](https://leetcode.com/problems/excel-sheet-column-title)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 169🔥 |[Majority Element](https://leetcode.com/problems/majority-element)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 171 |[Excel Sheet Column Number](https://leetcode.com/problems/excel-sheet-column-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 172 |[Factorial Trailing Zeroes](https://leetcode.com/problems/factorial-trailing-zeroes)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 179 |[Largest Number](https://leetcode.com/problems/largest-number/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 187 |[Repeated DNA Sequences](https://leetcode.com/problems/repeated-dna-sequences/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 188 |[Best Time to Buy and Sell Stock IV](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-iv/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 189 |[Rotate Array](https://leetcode.com/problems/rotate-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 190 |[Reverse Bits](https://leetcode.com/problems/reverse-bits)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 191 |[Number of 1 Bits](https://leetcode.com/problems/number-of-1-bits)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 198🔥 |[House Robber](https://leetcode.com/problems/house-robber)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 199 |[Binary Tree Right Side View](https://leetcode.com/problems/binary-tree-right-side-view/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 200🔥 |[Number of Islands](https://leetcode.com/problems/number-of-islands/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 201 |[Bitwise AND of Numbers Range](https://leetcode.com/problems/bitwise-and-of-numbers-range/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 202 |[Happy Number](https://leetcode.com/problems/happy-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 203 |[Remove Linked List Elements](https://leetcode.com/problems/remove-linked-list-elements)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 204 |[Count Primes](https://leetcode.com/problems/count-primes)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 205 |[Isomorphic Strings](https://leetcode.com/problems/isomorphic-strings)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 206🔥 |[Reverse Linked List](https://leetcode.com/problems/reverse-linked-list)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 207🔥 |[Course Schedule](https://leetcode.com/problems/course-schedule/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 208🔥 |[208. Implement Trie (Prefix Tree)](https://leetcode.com/problems/implement-trie-prefix-tree/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 209 |[Minimum Size Subarray Sum](https://leetcode.com/problems/minimum-size-subarray-sum/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 210 |[Course Schedule II](https://leetcode.com/problems/course-schedule-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 212 |[Word Search II](https://leetcode.com/problems/word-search-ii/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 213 |[House Robber II](https://leetcode.com/problems/house-robber-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 215🔥 |[Kth Largest Element in an Array](https://leetcode.com/problems/kth-largest-element-in-an-array/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 216 |[Combination Sum III](https://leetcode.com/problems/combination-sum-iii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 217 |[Contains Duplicate](https://leetcode.com/problems/contains-duplicate)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 218 |[The Skyline Problem](https://leetcode.com/problems/the-skyline-problem/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 219 |[Contains Duplicate II](https://leetcode.com/problems/contains-duplicate-ii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 220 |[Contains Duplicate III](https://leetcode.com/problems/contains-duplicate-iii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 221🔥 |[Maximal Square](https://leetcode.com/problems/maximal-square/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 222 |[Count Complete Tree Nodes](https://leetcode.com/problems/count-complete-tree-nodes/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 223 |[Rectangle Area](https://leetcode.com/problems/rectangle-area/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 225 |[Implement Stack using Queues](https://leetcode.com/problems/implement-stack-using-queues)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 226🔥 |[Invert Binary Tree](https://leetcode.com/problems/invert-binary-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 227 |[Basic Calculator II](https://leetcode.com/problems/basic-calculator-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 228 |[Summary Ranges](https://leetcode.com/problems/summary-ranges/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 229 |[Majority Element II](https://leetcode.com/problems/majority-element-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 230 |[Kth Smallest Element in a BST](https://leetcode.com/problems/kth-smallest-element-in-a-bst/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 231 |[Power of Two](https://leetcode.com/problems/power-of-two)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 232 |[Implement Queue using Stacks](https://leetcode.com/problems/implement-queue-using-stacks)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 233 |[Number of Digit One](https://leetcode.com/problems/number-of-digit-one/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 234🔥 |[Palindrome Linked List](https://leetcode.com/problems/palindrome-linked-list)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 235 |[Lowest Common Ancestor of a Binary Search Tree](https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-search-tree)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 236🔥 |[Lowest Common Ancestor of a Binary Tree](https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-tree/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 237 |[Delete Node in a Linked List](https://leetcode.com/problems/delete-node-in-a-linked-list)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 238🔥 |[Product of Array Except Self](https://leetcode.com/problems/product-of-array-except-self/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 239🔥 |[Sliding Window Maximum](https://leetcode.com/problems/sliding-window-maximum/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 240🔥 |[Search a 2D Matrix II](https://leetcode.com/problems/search-a-2d-matrix-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 241 |[Different Ways to Add Parentheses](https://leetcode.com/problems/different-ways-to-add-parentheses/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 242 |[Valid Anagram](https://leetcode.com/problems/valid-anagram)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 257 |[Binary Tree Paths](https://leetcode.com/problems/binary-tree-paths)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 258 |[Add Digits](https://leetcode.com/problems/add-digits)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 260 |[Single Number III](https://leetcode.com/problems/single-number-iii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 263 |[Ugly Number](https://leetcode.com/problems/ugly-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 264 |[Ugly Number II](https://leetcode.com/problems/ugly-number-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 268 |[Missing Number](https://leetcode.com/problems/missing-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 274 |[H-Index](https://leetcode.com/problems/h-index/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 275 |[H-Index II](https://leetcode.com/problems/h-index-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 278 |[First Bad Version](https://leetcode.com/problems/first-bad-version)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 279🔥 |[Perfect Squares](https://leetcode.com/problems/perfect-squares/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 283🔥 |[Move Zeroes](https://leetcode.com/problems/move-zeroes)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 287🔥 |[Find the Duplicate Number](https://leetcode.com/problems/find-the-duplicate-number/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 289 |[Game of Life](https://leetcode.com/problems/game-of-life/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 290 |[Word Pattern](https://leetcode.com/problems/word-pattern)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 292 |[Nim Game](https://leetcode.com/problems/nim-game)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 295 |[Find Median from Data Stream](https://leetcode.com/problems/find-median-from-data-stream/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 297🔥 |[Serialize and Deserialize Binary Tree](https://leetcode.com/problems/serialize-and-deserialize-binary-tree/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 300🔥 |[Longest Increasing Subsequence](https://leetcode.com/problems/longest-increasing-subsequence/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 301🔥 |[To Do](https://leetcode.com/problems/longest-increasing-subsequence/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 303 |[Range Sum Query - Immutable](https://leetcode.com/problems/range-sum-query-immutable)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 304 |[Range Sum Query 2D - Immutable](https://leetcode.com/problems/range-sum-query-2d-immutable/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 306 |[Additive Number](https://leetcode.com/problems/additive-number/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 307 |[Range Sum Query - Mutable](https://leetcode.com/problems/range-sum-query-mutable/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 309🔥 |[Best Time to Buy and Sell Stock with Cooldown](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-with-cooldown/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 310 |[Minimum Height Trees](https://leetcode.com/problems/minimum-height-trees/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 312🔥 |[Burst Balloons](https://leetcode.com/problems/burst-balloons/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 313 |[Super Ugly Number](https://leetcode.com/problems/super-ugly-number/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 315 |[Count of Smaller Numbers After Self](https://leetcode.com/problems/count-of-smaller-numbers-after-self/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 318 |[Maximum Product of Word Lengths](https://leetcode.com/problems/maximum-product-of-word-lengths/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 319 |[Bulb Switcher](https://leetcode.com/problems/bulb-switcher/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 322🔥 |[Coin Change](https://leetcode.com/problems/coin-change/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 324 |[Wiggle Sort II](https://leetcode.com/problems/wiggle-sort-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 326 |[Power of Three](https://leetcode.com/problems/power-of-three)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 328 |[Odd Even Linked List](https://leetcode.com/problems/odd-even-linked-list/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 329 |[Longest Increasing Path in a Matrix](https://leetcode.com/problems/longest-increasing-path-in-a-matrix/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 331 |[Verify Preorder Serialization of a Binary Tree](https://leetcode.com/problems/verify-preorder-serialization-of-a-binary-tree/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 332 |[Reconstruct Itinerary](https://leetcode.com/problems/reconstruct-itinerary/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 334 |[Increasing Triplet Subsequence](https://leetcode.com/problems/increasing-triplet-subsequence/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 337🔥 |[House Robber III](https://leetcode.com/problems/house-robber-iii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 338🔥 |[Counting Bits](https://leetcode.com/problems/counting-bits/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 341 |[Flatten Nested List Iterator](https://leetcode.com/problems/flatten-nested-list-iterator/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 342 |[Power of Four](https://leetcode.com/problems/power-of-four)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 343 |[Integer Break](https://leetcode.com/problems/integer-break/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 344 |[Reverse String](https://leetcode.com/problems/reverse-string)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 345 |[Reverse Vowels of a String](https://leetcode.com/problems/reverse-vowels-of-a-string)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 347🔥 |[Top K Frequent Elements](https://leetcode.com/problems/top-k-frequent-elements/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 349 |[Intersection of Two Arrays](https://leetcode.com/problems/intersection-of-two-arrays)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 350 |[Intersection of Two Arrays II](https://leetcode.com/problems/intersection-of-two-arrays-ii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 357 |[Count Numbers with Unique Digits](https://leetcode.com/problems/count-numbers-with-unique-digits/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 365 |[Water and Jug Problem](https://leetcode.com/problems/water-and-jug-problem/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 367 |[Valid Perfect Square](https://leetcode.com/problems/valid-perfect-square)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 368 |[Largest Divisible Subset](https://leetcode.com/problems/largest-divisible-subset/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 371 |[Sum of Two Integers](https://leetcode.com/problems/sum-of-two-integers)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 372 |[Super Pow](https://leetcode.com/problems/super-pow/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 373 |[Find K Pairs with Smallest Sums](https://leetcode.com/problems/find-k-pairs-with-smallest-sums/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 374 |[Guess Number Higher or Lower](https://leetcode.com/problems/guess-number-higher-or-lower)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 375 |[Guess Number Higher or Lower II](https://leetcode.com/problems/guess-number-higher-or-lower-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 376 |[Wiggle Subsequence](https://leetcode.com/problems/wiggle-subsequence/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 377 |[Combination Sum IV](https://leetcode.com/problems/combination-sum-iv/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 378 |[Kth Smallest Element in a Sorted Matrix](https://leetcode.com/problems/kth-smallest-element-in-a-sorted-matrix/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 380 |[Insert Delete GetRandom O(1)](https://leetcode.com/problems/insert-delete-getrandom-o1/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 381 |[Insert Delete GetRandom O(1) - Duplicates allowed](https://leetcode.com/problems/insert-delete-getrandom-o1-duplicates-allowed/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 382 |[Linked List Random Node](https://leetcode.com/problems/linked-list-random-node/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 383 |[Ransom Note](https://leetcode.com/problems/ransom-note)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 384 |[Shuffle an Array](https://leetcode.com/problems/shuffle-an-array/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 385 |[Mini Parser](https://leetcode.com/problems/mini-parser/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 386 |[Lexicographical Numbers](https://leetcode.com/problems/lexicographical-numbers/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 387 |[First Unique Character in a String](https://leetcode.com/problems/first-unique-character-in-a-string)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 388 |[Longest Absolute File Path](https://leetcode.com/problems/longest-absolute-file-path/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 389 |[Find the Difference](https://leetcode.com/problems/find-the-difference)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 390 |[Elimination Game](https://leetcode.com/problems/elimination-game/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 392 |[Is Subsequence](https://leetcode.com/problems/is-subsequence/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 393 |[UTF-8 Validation](https://leetcode.com/problems/utf-8-validation/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 394🔥 |[Decode String](https://leetcode.com/problems/decode-string/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 395 |[Longest Substring with At Least K Repeating Characters](https://leetcode.com/problems/longest-substring-with-at-least-k-repeating-characters/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 396 |[Rotate Function](https://leetcode.com/problems/rotate-function/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 397 |[Integer Replacement](https://leetcode.com/problems/integer-replacement/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 398 |[Random Pick Index](https://leetcode.com/problems/random-pick-index/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 399🔥 |[To Do](https://leetcode.com/problems/rotate-function/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 400 |[Nth Digit](https://leetcode.com/problems/nth-digit)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 404 |[Sum of Left Leaves](https://leetcode.com/problems/sum-of-left-leaves)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 405 |[Convert a Number to Hexadecimal](https://leetcode.com/problems/convert-a-number-to-hexadecimal)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 409 |[Longest Palindrome](https://leetcode.com/problems/longest-palindrome)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 412 |[Fizz Buzz](https://leetcode.com/problems/fizz-buzz/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 414 |[Third Maximum Number](https://leetcode.com/problems/third-maximum-number)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 415 |[Add Strings](https://leetcode.com/problems/add-strings)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 416🔥 |[Partition Equal Subset Sum](https://leetcode.com/problems/partition-equal-subset-sum/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 429 |[N-ary Tree Level Order Traversal](https://leetcode.com/problems/n-ary-tree-level-order-traversal)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 434 |[Number of Segments in a String](https://leetcode.com/problems/number-of-segments-in-a-string)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 437🔥 |[Path Sum III](https://leetcode.com/problems/path-sum-iii)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 438🔥 |[Find All Anagrams in a String](https://leetcode.com/problems/find-all-anagrams-in-a-string)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 441 |[Arranging Coins](https://leetcode.com/problems/arranging-coins)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 443 |[String Compression](https://leetcode.com/problems/string-compression)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 447 |[Number of Boomerangs](https://leetcode.com/problems/number-of-boomerangs)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 448🔥 |[Find All Numbers Disappeared in an Array](https://leetcode.com/problems/find-all-numbers-disappeared-in-an-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 453 |[Minimum Moves to Equal Array Elements](https://leetcode.com/problems/minimum-moves-to-equal-array-elements)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 454 |[4Sum II](https://leetcode.com/problems/4sum-ii/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 455 |[Assign Cookies](https://leetcode.com/problems/assign-cookies)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 459 |[Repeated Substring Pattern](https://leetcode.com/problems/repeated-substring-pattern)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 461🔥 |[Hamming Distance](https://leetcode.com/problems/hamming-distance)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 463 |[Island Perimeter](https://leetcode.com/problems/island-perimeter)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 474 |[Ones and Zeroes](https://leetcode.com/problems/ones-and-zeroes/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 475 |[Heaters](https://leetcode.com/problems/heaters)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 476 |[Number Complement](https://leetcode.com/problems/number-complement)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 485 |[Max Consecutive Ones](https://leetcode.com/problems/max-consecutive-ones)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 493 |[Reverse Pairs](https://leetcode.com/problems/reverse-pairs/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 494🔥 |[Target Sum](https://leetcode.com/problems/target-sum/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 496 |[Next Greater Element I](https://leetcode.com/problems/next-greater-element-i)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 500 |[Keyboard Row](https://leetcode.com/problems/keyboard-row)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 509 |[Fibonacci Number](https://leetcode.com/problems/fibonacci-number/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 532 |[K-diff Pairs in an Array](https://leetcode.com/problems/k-diff-pairs-in-an-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 561 |[Array Partition I](https://leetcode.com/problems/array-partition-i)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 566 |[Reshape the Matrix](https://leetcode.com/problems/reshape-the-matrix)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 572 |[Subtree of Another Tree](https://leetcode.com/problems/subtree-of-another-tree/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 581🔥 |[Shortest Unsorted Continuous Subarray](https://leetcode.com/problems/shortest-unsorted-continuous-subarray)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 605 |[Can Place Flowers](https://leetcode.com/problems/can-place-flowers)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 628 |[Maximum Product of Three Numbers](https://leetcode.com/problems/maximum-product-of-three-numbers)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 643 |[Maximum Average Subarray I](https://leetcode.com/problems/maximum-average-subarray-i)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 661 |[Image Smoother](https://leetcode.com/problems/image-smoother)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 665 |[Non-decreasing Array](https://leetcode.com/problems/non-decreasing-array)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 714 |[Best Time to Buy and Sell Stock with Transaction Fee](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-with-transaction-fee/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 829 |[Consecutive Numbers Sum](https://leetcode.com/problems/consecutive-numbers-sum/)|[Python](./code/Untitled.ipynb)|Hard|  |
# | 846 |[Hand of Straights](https://leetcode.com/problems/hand-of-straights/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 905 |[Sort Array By Parity](https://leetcode.com/problems/sort-array-by-parity/)|[Python](./code/Untitled.ipynb)|Easy|  |
# | 946 |[Validate Stack Sequences](https://leetcode.com/problems/validate-stack-sequences/)|[Python](./code/Untitled.ipynb)|Medium|  |
# | 1155 |[Number of Dice Rolls With Target Sum](https://leetcode.com/problems/number-of-dice-rolls-with-target-sum/)|[Python](solutions/1155.%2) |Medium|  |
